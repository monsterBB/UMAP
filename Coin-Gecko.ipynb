# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
import numpy as np
import copy
#from sklearn.preprocessing import StandardScale
from mpl_toolkits.mplot3d import Axes3D
import plotly

# %%
DT1 = pd.read_csv('DT1.csv')
DT2 = pd.read_csv('DT2.csv')

# %%
import plotly.express as px
df = DT1
fig = px.scatter_3d(df, x='PC1', y='PC2', z='PC3', color='clusters')
fig.show()
#fig.write_html("Coin-Gecko_PCA.html", include_plotlyjs="cdn")
import plotly.io as pio
pio.write_html(fig, file="Coin-Gecko_PCA.html", auto_open=True)
# Out:
# <div>                            <div id="f293f757-e042-4c87-8fdd-bbfbd5ef0bde" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f293f757-e042-4c87-8fdd-bbfbd5ef0bde")) {                    Plotly.newPlot(                        "f293f757-e042-4c87-8fdd-bbfbd5ef0bde",                        [{"hovertemplate": "PC1=%{x}<br>PC2=%{y}<br>PC3=%{z}<br>clusters=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [0, 1, 0, 2, 1, 2, 3, 0, 1, 2, 3, 1, 0, 3, 1, 1, 2, 0, 3, 1, 1, 1, 1, 0, 0, 3, 2, 3, 3, 2, 0, 3, 3, 2, 0, 0, 0, 2, 2, 0, 1, 0, 2, 0, 1, 1, 1, 0, 3, 2, 3, 1, 2, 2, 2, 0, 2, 0, 3, 2, 0, 0, 1, 2, 1, 0, 1, 1, 0, 1, 0, 2, 2, 2, 1, 1, 2, 1, 3, 0, 2, 1, 2, 2, 2, 2, 1, 3, 1, 0, 3, 1, 3, 0, 0, 3, 1, 1, 3, 3, 1, 0, 1, 1, 0, 2, 2, 0, 3, 0, 
# ...

# %%
df = DT2
fig = px.scatter_3d(df, x='D1', y='D2', z='D3', color='clusters')
fig.show()
#fig.write_html("Coin-Gecko_t-SNE.html", include_plotlyjs="cdn")
pio.write_html(fig, file="Coin-Gecko_t-SNE.html", auto_open=True)
# Out:
# <div>                            <div id="a309cf1d-8b33-4356-8213-4ffcaffd77b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a309cf1d-8b33-4356-8213-4ffcaffd77b6")) {                    Plotly.newPlot(                        "a309cf1d-8b33-4356-8213-4ffcaffd77b6",                        [{"hovertemplate": "D1=%{x}<br>D2=%{y}<br>D3=%{z}<br>clusters=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [0, 1, 0, 2, 1, 2, 3, 0, 1, 2, 3, 1, 0, 3, 1, 1, 2, 0, 3, 1, 1, 1, 1, 0, 0, 3, 2, 3, 3, 2, 0, 3, 3, 2, 0, 0, 0, 2, 2, 0, 1, 0, 2, 0, 1, 1, 1, 0, 3, 2, 3, 1, 2, 2, 2, 0, 2, 0, 3, 2, 0, 0, 1, 2, 1, 0, 1, 1, 0, 1, 0, 2, 2, 2, 1, 1, 2, 1, 3, 0, 2, 1, 2, 2, 2, 2, 1, 3, 1, 0, 3, 1, 3, 0, 0, 3, 1, 1, 3, 3, 1, 0, 1, 1, 0, 2, 2, 0, 3, 0, 2, 
# ...
